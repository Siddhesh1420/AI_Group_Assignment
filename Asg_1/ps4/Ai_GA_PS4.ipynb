# %% [markdown]
# # Cost Function

# %%
def n_conflict(state , course_pairs):

  count = 0

  for (c1,c2) in course_pairs:
    if state[c1-1] == state[c2-1]:
      count += 1

  return count


def n_excess_courses( state , S ):

    tot_count = 0

    for i in range(S):
      count = 0
      for slot in state:
        if slot == i+1 :
          count=count+1
      tot_count += max(0, count - 2)

    return tot_count

def calculate_cost(state , conflicts , S ):

    n_course_conf = n_conflict(state, conflicts)

    conf_penalty = n_course_conf * 10

    n_exc_courses = n_excess_courses(state , S)

    dist_penalty = n_exc_courses * 2

    return conf_penalty , dist_penalty , conf_penalty + dist_penalty

# %% [markdown]
# # Neighbor Generation

# %%
def generate_neighbors(initial_state , S):

  all_neighbours = []

  for i in range(len(initial_state)):
    for j in range(S):
      if initial_state[i] == j+1 :
        continue

      new_neighbour = initial_state.copy()
      new_neighbour[i] = j+1

      all_neighbours.append(new_neighbour)

  return all_neighbours

# %% [markdown]
# # Hill Climbing

# %%
def hill_climbing(initial_state , conflicts ,S):

  x , y , initial_state_cost = calculate_cost(initial_state , conflicts , S)

  all_neighbours = generate_neighbors(initial_state , S)

  best_neighbour = initial_state
  best_neighbour_cost = initial_state_cost

  for neighbour in all_neighbours:

    x , y , neighbour_cost = calculate_cost(neighbour , conflicts , S)

    if neighbour_cost < best_neighbour_cost:
      best_neighbour = neighbour
      best_neighbour_cost = neighbour_cost

  return best_neighbour , best_neighbour_cost

# %% [markdown]
# Main Function

# %%
import time as time

def main(N,S,K,conflicts,initial_state):

  start_time = time.time()
  print("========================================")
  print("Algorithm: Hill Climbing")
  print("Problem: Exam Timetable Optimization")
  print("========================================")

  print("Initial Timetable :")

  for i in range(N):
    print("C",(i+1),"-> Slot " ,initial_state[i])

  in_conflict_cost , in_dist_cost , in_total_cost = calculate_cost(initial_state , conflicts , S)
  print("Initial Conflict Cost = ",in_conflict_cost)
  print("Initial Distribution Cost = ",in_dist_cost)
  print("Initial Total Cost = ",in_total_cost)

  i=1
  final_state = initial_state
  final_cost = in_total_cost

  while(1):

    if final_cost == 0:                 # Ideal Solution
      break
    best_neighbour,best_neighbour_cost = hill_climbing(final_state , conflicts , S)

    print("----------------------------------------")
    print("Iteration ",i)
    print("Best Neighbor Timetable:")
    for j in range(N):
      print("C",(j+1),"-> Slot " ,best_neighbour[j])

    neighbour_conflict_cost , neighbour_dist_cost , neighbour_total_cost = calculate_cost(best_neighbour , conflicts , S)
    print("Conflict Cost = ",neighbour_conflict_cost)
    print("Distribution Cost = ",neighbour_dist_cost)
    print("Total Cost = ",neighbour_total_cost)

    if best_neighbour_cost >= final_cost:
      break

    final_state = best_neighbour
    final_cost = best_neighbour_cost
    i=i+1

  print("========================================")
  print("Final Timetable :")

  for j in range(N):
    print("C",(j+1),"-> Slot " ,final_state[j])

  conflict_cost , dist_cost , final_cost = calculate_cost(final_state , conflicts , S)
  print("Final Conflict Cost = ",conflict_cost)
  print("Final Distribution Cost = ",dist_cost)
  print("Final Total Cost = ",final_cost)

  print("Interations = ",i)
  print("Total Neighboring States Evaluated = ",(18*i))
  end_time = time.time()
  exec_time = end_time - start_time
  print("Execution Time = ",exec_time ," seconds")

  if final_cost == 0:
    termination_reason = "Global Optimum"
    print("Termination Reason: Global Optimum (Ideal Solution)")
  else:
    termination_reason = "Local Optimum"
    print("Termination Reason: Local Optimum")
  print("========================================")

  return in_total_cost, final_state , final_cost ,i , exec_time , termination_reason

# %% [markdown]
# # Experiments

# %%
N=6
S=4
K=8
conflicts = [(1,2),(1,3),(2,4),(2,5),(3,4),(3,6),(4,5),(5,6)]

initial_states = [ [1,2,3,1,2,1] , [2, 3, 1, 1, 4, 4] , [4, 2, 3, 1, 2, 3] ]

in_total_costs =[]
final_states = []
final_costs = []
iterations = []
exec_times = []
termination_reasons = []

# %% [markdown]
# ## Experiment 1

# %%
initial_state = initial_states[0]

in_total_cost, final_state , final_cost ,iteration , exec_time , termination_reason = main(N,S,K,conflicts,initial_state)

in_total_costs.append(in_total_cost)
final_states.append(final_state)
final_costs.append(final_cost)
iterations.append(iteration)
exec_times.append(exec_time)
termination_reasons.append(termination_reason)
# Out:
# ...
# Algorithm: Hill Climbing
# Problem: Exam Timetable Optimization
# ...
# Initial Timetable :
# C 1 -> Slot  1
# C 2 -> Slot  2
# C 3 -> Slot  3
# C 4 -> Slot  1
# C 5 -> Slot  2
# C 6 -> Slot  1
# Initial Conflict Cost =  10
# Initial Distribution Cost =  2
# Initial Total Cost =  12
# ----------------------------------------
# Iteration  1
# Best Neighbor Timetable:
# C 1 -> Slot  1
# C 2 -> Slot  3
# C 3 -> Slot  3
# C 4 -> Slot  1
# C 5 -> Slot  2
# C 6 -> Slot  1
# Conflict Cost =  0
# Distribution Cost =  2
# Total Cost =  2
# ----------------------------------------
# Iteration  2
# Best Neighbor Timetable:
# C 1 -> Slot  2
# C 2 -> Slot  3
# C 3 -> Slot  3
# C 4 -> Slot  1
# C 5 -> Slot  2
# C 6 -> Slot  1
# Conflict Cost =  0
# Distribution Cost =  0
# Total Cost =  0
# ...
# Final Timetable :
# C 1 -> Slot  2
# C 2 -> Slot  3
# C 3 -> Slot  3
# C 4 -> Slot  1
# C 5 -> Slot  2
# C 6 -> Slot  1
# Final Conflict Cost =  0
# Final Distribution Cost =  0
# Final Total Cost =  0
# ...

# %% [markdown]
# # Experiment 2

# %%
initial_state = initial_states[1]

in_total_cost, final_state , final_cost ,iteration , exec_time , termination_reason = main(N,S,K,conflicts,initial_state)

in_total_costs.append(in_total_cost)
final_states.append(final_state)
final_costs.append(final_cost)
iterations.append(iteration)
exec_times.append(exec_time)
termination_reasons.append(termination_reason)
# Out:
# ...
# Algorithm: Hill Climbing
# Problem: Exam Timetable Optimization
# ...
# Initial Timetable :
# C 1 -> Slot  2
# C 2 -> Slot  3
# C 3 -> Slot  1
# C 4 -> Slot  1
# C 5 -> Slot  4
# C 6 -> Slot  4
# Initial Conflict Cost =  20
# Initial Distribution Cost =  0
# Initial Total Cost =  20
# ----------------------------------------
# Iteration  1
# Best Neighbor Timetable:
# C 1 -> Slot  2
# C 2 -> Slot  3
# C 3 -> Slot  3
# C 4 -> Slot  1
# C 5 -> Slot  4
# C 6 -> Slot  4
# Conflict Cost =  10
# Distribution Cost =  0
# Total Cost =  10
# ----------------------------------------
# Iteration  2
# Best Neighbor Timetable:
# C 1 -> Slot  2
# C 2 -> Slot  3
# C 3 -> Slot  3
# C 4 -> Slot  1
# C 5 -> Slot  2
# C 6 -> Slot  4
# Conflict Cost =  0
# Distribution Cost =  0
# Total Cost =  0
# ...
# Final Timetable :
# C 1 -> Slot  2
# C 2 -> Slot  3
# C 3 -> Slot  3
# C 4 -> Slot  1
# C 5 -> Slot  2
# C 6 -> Slot  4
# Final Conflict Cost =  0
# Final Distribution Cost =  0
# Final Total Cost =  0
# ...

# %% [markdown]
# # Experiment 3

# %%
initial_state = initial_states[2]

in_total_cost, final_state , final_cost ,iteration , exec_time , termination_reason = main(N,S,K,conflicts,initial_state)

in_total_costs.append(in_total_cost)
final_states.append(final_state)
final_costs.append(final_cost)
iterations.append(iteration)
exec_times.append(exec_time)
termination_reasons.append(termination_reason)
# Out:
# ...
# Algorithm: Hill Climbing
# Problem: Exam Timetable Optimization
# ...
# Initial Timetable :
# C 1 -> Slot  4
# C 2 -> Slot  2
# C 3 -> Slot  3
# C 4 -> Slot  1
# C 5 -> Slot  2
# C 6 -> Slot  3
# Initial Conflict Cost =  20
# Initial Distribution Cost =  0
# Initial Total Cost =  20
# ----------------------------------------
# Iteration  1
# Best Neighbor Timetable:
# C 1 -> Slot  4
# C 2 -> Slot  2
# C 3 -> Slot  3
# C 4 -> Slot  1
# C 5 -> Slot  4
# C 6 -> Slot  3
# Conflict Cost =  10
# Distribution Cost =  0
# Total Cost =  10
# ----------------------------------------
# Iteration  2
# Best Neighbor Timetable:
# C 1 -> Slot  4
# C 2 -> Slot  2
# C 3 -> Slot  2
# C 4 -> Slot  1
# C 5 -> Slot  4
# C 6 -> Slot  3
# Conflict Cost =  0
# Distribution Cost =  0
# Total Cost =  0
# ...
# Final Timetable :
# C 1 -> Slot  4
# C 2 -> Slot  2
# C 3 -> Slot  2
# C 4 -> Slot  1
# C 5 -> Slot  4
# C 6 -> Slot  3
# Final Conflict Cost =  0
# Final Distribution Cost =  0
# Final Total Cost =  0
# ...

# %% [markdown]
# # Comparison Table

# %% [markdown]
# |Experiment|Intial State|Intial Cost|Final State|Final Cost|Iterations|Neighbors Evaluated|Execution Time|
# |:---|:----:|:----:|:---:|:----:|:-----:|:----:|---:|
# |1|[1,1,2,3,4,2]|12|[2,3,3,1,2,1]|0|3|54|0.0014505386352539062s|
# |2|[2,3,1,1,4,4]|20|[2,3,3,1,2,4]|0|3|54|0.0012793540954589844s|
# |3|[4,2,3,1,2,3]|20|[4,2,2,1,4,3]|0|3|54|0.0013310909271240234s|

# %% [markdown]
# # Input Processing

# %%
#N , S = map( int , input().split())
#K = int(input())
#conflicts = []
#
#for i in range(K):
#  c1 , c2 = map(int , input().split())
#  conflicts.append((c1,c2))
#
#initial_state = list(map(int , input().split()))
